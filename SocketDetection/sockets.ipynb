# %% [markdown]
# Training

# %%
# ✅ STEP 1: Install YOLOv8 (Ultralytics)
# !pip install -q ultralytics

# ✅ STEP 2: Import YOLO
from ultralytics import YOLO

# ✅ STEP 3: Set path to your data.yaml
# Note: Use raw string (r"") to handle Windows backslashes
data_yaml_path = r"C:\Users\matth\Downloads\Matthias_Scicluna_Thesis_SWD6.3A.v7i.yolov8\data.yaml"

# ✅ STEP 4: Train YOLOv8 model
model = YOLO("yolov8n.pt")  # You can change to yolov8s.pt or yolov8m.pt if needed

results = model.train(
    data=data_yaml_path,
    epochs=50,
    imgsz=640,
    batch=16,
    project='cpu_socket_detection',
    name='yolov8n_socket',
    exist_ok=True  # Overwrites old run if it exists
)
# Out:
# [notice] A new release of pip is available: 23.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Ultralytics 8.3.173  Python-3.10.11 torch-2.7.1+cpu CPU (13th Gen Intel Core(TM) i9-13900K)
# ...

# %% [markdown]
# Socket Detection Program

# %%
from ultralytics import YOLO
import os

model_path = r"cpu_socket_detection\yolov8n_socket\weights\best.pt"
model = YOLO(model_path)

# Test image path
image_path = r"lga1700_open.jpg"  

# Run detection
results = model.predict(source=image_path, save=True, imgsz=640, conf=0.3)

# Handle output
predicted_classes = results[0].boxes.cls.tolist() if results[0].boxes else []
class_names = results[0].names

if not predicted_classes:
    print(f"🟡 No socket detected in: {os.path.basename(image_path)} → Marked as 'Uncategorized'")
else:
    for i in predicted_classes:
        label = class_names[int(i)]
        print(f"🟢 Detected: {label}")
# Out:
# image 1/1 c:\Users\matth\OneDrive\Desktop\Thesis code\SocketDetection\lga1700_open.jpg: 640x480 1 LGA-1700, 59.3ms
# Speed: 3.3ms preprocess, 59.3ms inference, 4.7ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs\detect\predict2
# 🟢 Detected: LGA-1700

# %% [markdown]
# Pin Detection - Split in boxes

# %%
import os
import cv2
from ultralytics import YOLO

# === CONFIG ===
yolo_model_path = r"cpu_socket_detection/yolov8n_socket/weights/best.pt"
damaged_images_folder = r"am5 damaged"
output_tiles_folder = r"tiles_am5_damaged"
grid_rows, grid_cols = 8, 8
resize_tile = (128, 128)

# === Load YOLO socket detection model ===
model = YOLO(yolo_model_path)
os.makedirs(output_tiles_folder, exist_ok=True)

# === Process all damaged images ===
for filename in os.listdir(damaged_images_folder):
    if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
        image_path = os.path.join(damaged_images_folder, filename)
        results = model.predict(source=image_path, conf=0.3, save=False)
        boxes = results[0].boxes

        if not boxes or len(boxes) == 0:
            print(f"⚠️ No socket detected in {filename}")
            continue

        # Get the first box
        x1, y1, x2, y2 = map(int, boxes.xyxy[0])
        img = cv2.imread(image_path)

# ⬇️ Trim off top 20% and bottom 10% of the bounding box to exclude the die
        box_height = y2 - y1
        y1 += int(box_height * 0.2)
        y2 -= int(box_height * 0.1)

        socket_crop = img[y1:y2, x1:x2]

        h, w = socket_crop.shape[:2]
        tile_h, tile_w = h // grid_rows, w // grid_cols
        base_name = os.path.splitext(filename)[0]

        for i in range(grid_rows):
            for j in range(grid_cols):
                y_start = i * tile_h
                x_start = j * tile_w
                tile = socket_crop[y_start:y_start + tile_h, x_start:x_start + tile_w]
                tile = cv2.resize(tile, resize_tile)
                tile_filename = f"{base_name}_r{i}_c{j}.jpg"
                cv2.imwrite(os.path.join(output_tiles_folder, tile_filename), tile)

print("✅ Done! Tiles saved to:", output_tiles_folder)
# Out:
# image 1/1 c:\Users\matth\OneDrive\Desktop\Thesis code\SocketDetection\am5 damaged\1_image-108.png: 640x640 1 AM4, 31.8ms
# Speed: 1.6ms preprocess, 31.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\matth\OneDrive\Desktop\Thesis code\SocketDetection\am5 damaged\am5-missing-pins.jpg: 640x640 (no detections), 34.4ms
# Speed: 2.5ms preprocess, 34.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ No socket detected in am5-missing-pins.jpg
#
# image 1/1 c:\Users\matth\OneDrive\Desktop\Thesis code\SocketDetection\am5 damaged\bent-am5-socket-pins.jpg: 608x640 1 AM5, 31.5ms
# Speed: 1.6ms preprocess, 31.5ms inference, 0.4ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 c:\Users\matth\OneDrive\Desktop\Thesis code\SocketDetection\am5 damaged\bent-pins-am5.jpg: 608x640 1 AM5, 29.6ms
# Speed: 1.8ms preprocess, 29.6ms inference, 0.4ms postprocess per image at shape (1, 3, 608, 640)
#
# ...

# %% [markdown]
# Tile Training

# %%
from ultralytics import YOLO

model = YOLO("yolov8n-cls.pt")  # or yolov8s-cls.pt for higher accuracy

results = model.train(
    data=r"C:\Users\matth\OneDrive\Desktop\Thesis code\tiles_classification\dataset.yaml",
    epochs=50,
    imgsz=128,
    batch=16,
    project='pin_fault_classification',
    name='yolov8n_tile_classifier',
    exist_ok=True
)
